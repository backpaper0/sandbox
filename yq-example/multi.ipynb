# %% [markdown]
# # ひとつのファイル内にある複数のYAMLを扱う
#
# `-s`でひとつのYAMLにまとめてからインデックスで取り出せばよい。

# %%
cat multi.yaml
# Out:
# ---
# a: foo
# b: bar
# ---
# c: baz
# d: qux

# %%
cat multi.yaml | yq
# Out:
# {
#   "a": "foo",
#   "b": "bar"
# }
# {
#   "c": "baz",
#   "d": "qux"
# }

# %%
cat multi.yaml | yq -s '.[0]'
# Out:
# {
#   "a": "foo",
#   "b": "bar"
# }

# %%
cat multi.yaml | yq -s '.[1]'
# Out:
# {
#   "c": "baz",
#   "d": "qux"
# }
